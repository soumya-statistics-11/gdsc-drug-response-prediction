# %% [markdown]
# <a href="https://colab.research.google.com/github/soumya-statistics-11/Explainable-AI-for-Cancer-Drug-Sensitivity-Prediction/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics
from scipy import stats

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Deep Learning
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Explainable AI
import shap

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/GDSC_DATASET.csv")

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    df[col] = df[col].fillna('Unknown')

# %%
median_ic50 = df['LN_IC50'].median()

df['Response'] = (df['LN_IC50'] < median_ic50).astype(int)

# %%
drop_cols = [
    'COSMIC_ID',
    'CELL_LINE_NAME',
    'DRUG_ID',
    'LN_IC50',
    'AUC',
    'Z_SCORE'
]
df_model=df.drop(columns=drop_cols)

# %%
X = df_model.drop('Response', axis=1)

y = df_model['Response']

# %%
x=pd.get_dummies(X,drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (193628, 642)
# (48407, 642)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix,classification_report
accuracy_score(y_test,y_pred)
# Out:
# 0.8229388311607825

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     24237
#            1       0.82      0.83      0.82     24170
#
#     accuracy                           0.82     48407
#    macro avg       0.82      0.82      0.82     48407
# weighted avg       0.82      0.82      0.82     48407

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Accuracy: 0.8150474104984816

# %%
print(X.columns.tolist())
# Out:
# ['TCGA_DESC', 'DRUG_NAME', 'AUC', 'Z_SCORE', 'GDSC Tissue descriptor 1', 'GDSC Tissue descriptor 2', 'Cancer Type (matching TCGA label)', 'Microsatellite instability Status (MSI)', 'Screen Medium', 'Growth Properties', 'CNA', 'Gene Expression', 'Methylation', 'TARGET', 'TARGET_PATHWAY']

# %%
importance.head(20)
# Out:
#                                    importance
# AUC                                  0.357308
# Z_SCORE                              0.173602
# Growth Properties_Suspension         0.007839
# TARGET_PATHWAY_Mitosis               0.006285
# DRUG_NAME_SGC0946                    0.005806
# Screen Medium_R                      0.005694
# TARGET_TOP1                          0.005058
# TARGET_EGFR                          0.004649
# TARGET_PATHWAY_Other                 0.004604
# GDSC Tissue descriptor 1_leukemia    0.004374

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_rf)
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d')
plt.show()

# %%
importance=pd.DataFrame(rf.feature_importances_,index=X_train.columns,columns=['importance']).sort_values('importance',ascending=False).head(10)

# %%
importance
# Out:
#                                    importance
# AUC                                  0.357308
# Z_SCORE                              0.173602
# Growth Properties_Suspension         0.007839
# TARGET_PATHWAY_Mitosis               0.006285
# DRUG_NAME_SGC0946                    0.005806
# Screen Medium_R                      0.005694
# TARGET_TOP1                          0.005058
# TARGET_EGFR                          0.004649
# TARGET_PATHWAY_Other                 0.004604
# GDSC Tissue descriptor 1_leukemia    0.004374

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=importance.index,y=importance['importance'])
plt.xticks(rotation=90)
plt.show()

# %%
xgb = XGBClassifier(
    n_estimators=100,
    random_state=42
)

xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.8113289400293346

# %%
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X_train, y_train, epochs=10, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9480 - loss: 0.1274 - val_accuracy: 0.9722 - val_loss: 0.0662
# Epoch 2/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9775 - loss: 0.0548 - val_accuracy: 0.9773 - val_loss: 0.0505
# Epoch 3/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9808 - loss: 0.0443 - val_accuracy: 0.9786 - val_loss: 0.0472
# Epoch 4/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9822 - loss: 0.0397 - val_accuracy: 0.9822 - val_loss: 0.0408
# Epoch 5/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9842 - loss: 0.0347 - val_accuracy: 0.9803 - val_loss: 0.0433
# Epoch 6/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9856 - loss: 0.0318 - val_accuracy: 0.9826 - val_loss: 0.0389
# Epoch 7/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9866 - loss: 0.0294 - val_accuracy: 0.9809 - val_loss: 0.0419
# Epoch 8/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9871 - loss: 0.0288 - val_accuracy: 0.9838 - val_loss: 0.0339
# Epoch 9/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9881 - loss: 0.0266 - val_accuracy: 0.9823 - val_loss: 0.0391
# Epoch 10/10
# 606/606 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9884 - loss: 0.0257 - val_accuracy: 0.9812 - val_loss: 0.0416

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])


plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
import shap

explainer = shap.TreeExplainer(xgb)

shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(
    shap_values,
    X_test
)

# %%
probs = xgb.predict_proba(X_test)
probs[:10]
# Out:
# array([[2.5386810e-03, 9.9746132e-01],
#        [4.1121244e-04, 9.9958879e-01],
#        [5.0579810e-01, 4.9420193e-01],
#        [9.2842579e-03, 9.9071574e-01],
#        [1.2891293e-03, 9.9871087e-01],
#        [1.3309717e-03, 9.9866903e-01],
#        [2.6584327e-02, 9.7341567e-01],
#        [8.5146242e-01, 1.4853756e-01],
#        [9.3623400e-03, 9.9063766e-01],
#        [9.4335687e-01, 5.6643151e-02]], dtype=float32)
