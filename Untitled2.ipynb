# %% [markdown]
# <a href="https://colab.research.google.com/github/soumya-statistics-11/Explainable-AI-for-Cancer-Drug-Sensitivity-Prediction/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics
from scipy import stats

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Deep Learning
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Explainable AI
import shap

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/drive/MyDrive/Data/GDSC_DATASET.csv")

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    df[col] = df[col].fillna('Unknown')

# %%
median_ic50 = df['LN_IC50'].median()

df['Response'] = (df['LN_IC50'] < median_ic50).astype(int)

# %%
drop_cols = [
    'COSMIC_ID',
    'CELL_LINE_NAME',
    'DRUG_ID',
    'LN_IC50',
    'AUC',
    'Z_SCORE'
]
df_model=df.drop(columns=drop_cols)

# %%
X = df_model.drop('Response', axis=1)

y = df_model['Response']

# %%
X_cat = df_model.drop('Response', axis=1)

y_cat = df_model['Response']

# %%
#For CatBoost
cat_features = X_cat.select_dtypes(include=['object']).columns

print(cat_features)
# Out:
# Index(['TCGA_DESC', 'DRUG_NAME', 'GDSC Tissue descriptor 1',
#        'GDSC Tissue descriptor 2', 'Cancer Type (matching TCGA label)',
#        'Microsatellite instability Status (MSI)', 'Screen Medium',
#        'Growth Properties', 'CNA', 'Gene Expression', 'Methylation', 'TARGET',
#        'TARGET_PATHWAY'],
#       dtype='object')

# %%
x=pd.get_dummies(X,drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (193628, 642)
# (48407, 642)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred_lr=lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix,classification_report
accuracy_score(y_test,y_pred)
# Out:
# 0.8229388311607825

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     24237
#            1       0.82      0.83      0.82     24170
#
#     accuracy                           0.82     48407
#    macro avg       0.82      0.82      0.82     48407
# weighted avg       0.82      0.82      0.82     48407

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Accuracy: 0.8150474104984816

# %%
print(X.columns.tolist())
# Out:
# ['TCGA_DESC', 'DRUG_NAME', 'GDSC Tissue descriptor 1', 'GDSC Tissue descriptor 2', 'Cancer Type (matching TCGA label)', 'Microsatellite instability Status (MSI)', 'Screen Medium', 'Growth Properties', 'CNA', 'Gene Expression', 'Methylation', 'TARGET', 'TARGET_PATHWAY']

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_rf)
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d')
plt.show()

# %%
importance=pd.DataFrame(rf.feature_importances_,index=X_train.columns,columns=['importance']).sort_values('importance',ascending=False).head(10)

# %%
importance.head(20)
# Out:
#                                                    importance
# Screen Medium_R                                      0.039564
# Growth Properties_Suspension                         0.018348
# Microsatellite instability Status (MSI)_MSS/MSI-L    0.016921
# TARGET_TOP1                                          0.011966
# TARGET_PATHWAY_Mitosis                               0.010940
# Growth Properties_Semi-Adherent                      0.010565
# GDSC Tissue descriptor 1_leukemia                    0.009100
# Methylation_Y                                        0.008979
# TARGET_PATHWAY_Other                                 0.008798
# Gene Expression_Y                                    0.007884

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=importance.index,y=importance['importance'])
plt.xticks(rotation=90)
plt.show()

# %%
xgb = XGBClassifier(
    n_estimators=100,
    random_state=42
)

xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.8113289400293346

# %% [markdown]
# # **ROC-AOC**

# %%
#For logistic Regression
y_prob_lr = lr.predict_proba(X_test)[:,1]

auc_lr = roc_auc_score(y_test, y_prob_lr)

print("ROC-AUC:", auc_lr)
# Out:
# ROC-AUC: 0.9105235665067151

# %%
#For random forest
y_prob_rf = rf.predict_proba(X_test)[:,1]

auc_rf = roc_auc_score(y_test, y_prob_rf)

print("ROC-AUC:", auc_rf)
# Out:
# ROC-AUC: 0.89825038921863

# %%
#For XGBoost
y_prob_xgb = xgb.predict_proba(X_test)[:,1]

auc_xgb = roc_auc_score(y_test, y_prob_xgb)

print("ROC-AUC:", auc_xgb)
# Out:
# ROC-AUC: 0.9036301184812527

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr_lr, tpr_lr, _ = roc_curve(y_test, y_prob_lr)
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob_rf)
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_prob_xgb)

plt.figure(figsize=(8,6))

plt.plot(fpr_lr, tpr_lr,
         label=f'Logistic Regression (AUC={auc_lr:.3f})')

plt.plot(fpr_rf, tpr_rf,
         label=f'Random Forest (AUC={auc_rf:.3f})')

plt.plot(fpr_xgb, tpr_xgb,
         label=f'XGBoost (AUC={auc_xgb:.3f})')

plt.plot([0,1],[0,1],'k--')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend()

plt.show()

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression',
              'Random Forest',
              'XGBoost'],
    'Accuracy': [0.8229,
                 0.8150,
                 0.8113] , 'ROC-AUC': [0.9105,
                                       0.8982,
                                       0.9036]
})

results
# Out:
#                  Model  Accuracy  ROC-AUC
# 0  Logistic Regression    0.8229   0.9105
# 1        Random Forest    0.8150   0.8982
# 2              XGBoost    0.8113   0.9036

# %% [markdown]
# # **Cat-Boost**

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 5.9 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostClassifier

# %%
cat = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    verbose=100
)

cat.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6831092	total: 123ms	remaining: 1m 1s
# 100:	learn: 0.4880318	total: 7.47s	remaining: 29.5s
# 200:	learn: 0.4338138	total: 12.9s	remaining: 19.2s
# 300:	learn: 0.4073537	total: 24.2s	remaining: 16s
# 400:	learn: 0.3912649	total: 32s	remaining: 7.91s
# 499:	learn: 0.3798317	total: 37.8s	remaining: 0us
# CatBoostClassifier(depth=6, iterations=500, learning_rate=0.1, verbose=100)

# %%
y_pred_cat = cat.predict(X_test)
from sklearn.metrics import accuracy_score

print(
    accuracy_score(y_test, y_pred_cat)
)
# Out:
# 0.8277315264321276

# %% [markdown]
# Before One hot encoding

# %%
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(
    X_cat,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=y_cat
)

# %%
from catboost import CatBoostClassifier

cat_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    eval_metric='AUC',
    random_seed=42,
    verbose=100
)

cat_model.fit(
    X_train_cat,
    y_train_cat,
    cat_features=list(cat_features),
    verbose=100
)
# Out:
# 0:	total: 550ms	remaining: 4m 34s
# 100:	total: 1m 17s	remaining: 5m 6s
# 200:	total: 2m 29s	remaining: 3m 43s
# 300:	total: 3m 43s	remaining: 2m 27s
# 400:	total: 4m 55s	remaining: 1m 13s
# 499:	total: 6m 10s	remaining: 0us
# CatBoostClassifier(depth=6, eval_metric='AUC', iterations=500, learning_rate=0.1, random_seed=42, verbose=100)

# %%
from sklearn.metrics import accuracy_score

y_pred_cat = cat_model.predict(X_test_cat)

print(
    accuracy_score(y_test_cat, y_pred_cat)
)
# Out:
# 0.8345074059536843

# %%
from sklearn.metrics import roc_auc_score

y_prob_cat = cat_model.predict_proba(X_test_cat)[:,1]

auc_cat = roc_auc_score(y_test_cat, y_prob_cat)

print("ROC-AUC:", auc_cat)
# Out:
# ROC-AUC: 0.9216494860618594

# %%
importance = pd.DataFrame({
    'Feature': X_train_cat.columns,
    'Importance': cat_model.get_feature_importance()
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

importance.head(20)
# Out:
#                                     Feature  Importance
# 1                                 DRUG_NAME   51.504444
# 3                  GDSC Tissue descriptor 2   10.474636
# 2                  GDSC Tissue descriptor 1    7.626003
# 7                         Growth Properties    7.041315
# 11                                   TARGET    4.955285
# 0                                 TCGA_DESC    4.871305
# 6                             Screen Medium    3.700673
# 12                           TARGET_PATHWAY    2.813891
# 4         Cancer Type (matching TCGA label)    2.160506
# 9                           Gene Expression    1.824708
# 5   Microsatellite instability Status (MSI)    1.376906
# 10                              Methylation    0.960791
# 8                                       CNA    0.689536

# %% [markdown]
# # **Neural Network**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler(with_mean=False)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(
    128,
    activation='relu',
    input_shape=(X_train_scaled.shape[1],)
))

model.add(Dropout(0.3))

model.add(Dense(
    64,
    activation='relu'
))

model.add(Dropout(0.3))

model.add(Dense(
    32,
    activation='relu'
))

model.add(Dense(
    1,
    activation='sigmoid'
))

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=512,
    verbose=1
)
# Out:
# Epoch 1/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - accuracy: 0.7879 - loss: 0.4392 - val_accuracy: 0.8231 - val_loss: 0.3756
# Epoch 2/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8207 - loss: 0.3816 - val_accuracy: 0.8255 - val_loss: 0.3714
# Epoch 3/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8260 - loss: 0.3724 - val_accuracy: 0.8264 - val_loss: 0.3670
# Epoch 4/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8286 - loss: 0.3671 - val_accuracy: 0.8271 - val_loss: 0.3662
# Epoch 5/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8317 - loss: 0.3627 - val_accuracy: 0.8292 - val_loss: 0.3639
# Epoch 6/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.8322 - loss: 0.3595 - val_accuracy: 0.8297 - val_loss: 0.3666
# Epoch 7/20
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8335 - loss: 0.3569 - val_accuracy: 0.8307 - val_loss: 0.3625
# Epoch 8/20
# ...

# %%
loss, accuracy = model.evaluate(
    X_test_scaled,
    y_test
)

print("Test Accuracy:", accuracy)
# Out:
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8324 - loss: 0.3599
# Test Accuracy: 0.8324002623558044

# %%
from sklearn.metrics import roc_auc_score

y_prob_nn = model.predict(
    X_test_scaled
)

auc_nn = roc_auc_score(
    y_test,
    y_prob_nn
)

print("ROC-AUC:", auc_nn)
# Out:
# 1513/1513 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# ROC-AUC: 0.9183376877442277

# %% [markdown]
# # **Feature Importance**

# %%
importance = pd.DataFrame({
    'Feature': X_train_cat.columns,
    'Importance': cat_model.get_feature_importance()
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

importance.head(20)
# Out:
#                                     Feature  Importance
# 1                                 DRUG_NAME   51.504444
# 3                  GDSC Tissue descriptor 2   10.474636
# 2                  GDSC Tissue descriptor 1    7.626003
# 7                         Growth Properties    7.041315
# 11                                   TARGET    4.955285
# 0                                 TCGA_DESC    4.871305
# 6                             Screen Medium    3.700673
# 12                           TARGET_PATHWAY    2.813891
# 4         Cancer Type (matching TCGA label)    2.160506
# 9                           Gene Expression    1.824708
# 5   Microsatellite instability Status (MSI)    1.376906
# 10                              Methylation    0.960791
# 8                                       CNA    0.689536

# %%
top20 = importance.head(20)

plt.figure(figsize=(10,8))

sns.barplot(
    x='Importance',
    y='Feature',
    data=top20
)

plt.title('Top 20 Important Features - CatBoost')
plt.show()

# %% [markdown]
# # **SHAP Analysis**

# %%
import shap

explainer = shap.TreeExplainer(cat_model)

shap_values = explainer.shap_values(X_test_cat)

# %%
shap.summary_plot(
    shap_values,
    X_test_cat
)

# %%
shap.plots.bar(shap_values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1046/1878661088.py in <cell line: 0>()
# ----> 1 shap.plots.bar(shap_values)
#
# /usr/local/lib/python3.12/dist-packages/shap/plots/_bar.py in bar(shap_values, max_display, order, clustering, clustering_cutoff, show_data, ax, show)
#      89             "object, or dictionary of Explanation objects!"
#      90         )
# ---> 91         raise TypeError(emsg)
#      92
#      93     # unpack our list of Explanation objects we need to plot
#
# TypeError: The shap_values argument must be an Explanation object, Cohorts object, or dictionary of Explanation objects!
